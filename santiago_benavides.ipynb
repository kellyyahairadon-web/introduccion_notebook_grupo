# %% [markdown]
# ## KEVIN SANTIAGO BENAVIDES RODRIGUEZ
# ingeneria ambiental
#
# La programacion permite obtener y analizar en un tiempo corto datos como calidad de agua o contaminantes que se encuentre en el medio

# %%
print("La conservacion de los ecosistemas es muy importante ya que estos ayudan a un equilibrio")
# Out:
# La conservacion de los ecosistemas es muy importante ya que estos ayudan a un equilibrio
