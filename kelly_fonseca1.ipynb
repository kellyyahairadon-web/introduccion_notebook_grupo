# %% [markdown]
# ## KELLY YAJAIRA FONSECA SALGUERO
# Ingeneria ambiental
# La programacion permite analizar datos ambientales como lo es la calidad del agua y emeisiones atmofericas de manera mas facil.facilitando la modelacion de escenarios climaticos y se optimiza la gestion de recursos naturales.

# %%
print("La calidad del agua se mide teniendo en cuenta su pH , tubidez entre otros ")
# Out:
# La calidad del agua se mide teniendo en cuenta su pH , tubidez entre otros
