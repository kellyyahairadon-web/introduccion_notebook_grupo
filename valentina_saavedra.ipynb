# %% [markdown]
# ## LUISA VALENTINA SAAVEDRA SOTO
# ingeneria ambiental
# la programación ayuda a la ingeniería ambiental principalmente en el modelado, simulación y análisis de datos complejos para predecir impactos, mejorar la eficiencia de recursos y gestionar la calidad ambiental

# %%
print("Los liquenes son un bioindicador del aire ")
# Out:
# Los liquenes son un bioindicador del aire
